# %% [markdown]
# <a href="https://colab.research.google.com/github/tongchen12/Complete-Python-3-Bootcamp/blob/master/Assignment_1_tongchen12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
files = "https://github.com/rpi-techfundamentals/hm-01-starter/raw/master/files.zip" 
# !pip install git+https://github.com/data-8/Gofer-Grader && wget $files && unzip -o files.zip
# Out:
# Collecting git+https://github.com/data-8/Gofer-Grader
#   Cloning https://github.com/data-8/Gofer-Grader to /tmp/pip-req-build-ffzpy9c5
#   Running command git clone -q https://github.com/data-8/Gofer-Grader /tmp/pip-req-build-ffzpy9c5
# Requirement already satisfied (use --upgrade to upgrade): gofer-grader==1.0.9 from git+https://github.com/data-8/Gofer-Grader in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from gofer-grader==1.0.9) (2.10.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from gofer-grader==1.0.9) (2.1.3)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from gofer-grader==1.0.9) (4.5.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->gofer-grader==1.0.9) (1.1.1)
# Building wheels for collected packages: gofer-grader
#   Building wheel for gofer-grader (setup.py) ... done
#   Created wheel for gofer-grader: filename=gofer_grader-1.0.9-cp36-none-any.whl size=10115 sha256=228bd356f423d4e05eefa1e6a9d0bd057fdbb8cca5c6e6e08cb503e5ad920d0e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cwxrf6zm/wheels/9e/62/24/8563ae039051d6ba979557d1766bfebbda5dd08f8572e3e35d
# Successfully built gofer-grader
# --2019-09-03 20:09:25--  https://github.com/rpi-techfundamentals/hm-01-starter/raw/master/files.zip
# Resolving github.com (github.com)... 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rpi-techfundamentals/hm-01-starter/master/files.zip [following]
# --2019-09-03 20:09:25--  https://raw.githubusercontent.com/rpi-techfundamentals/hm-01-starter/master/files.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 410260 (401K) [application/zip]
# Saving to: ‘files.zip.3’
#
# files.zip.3         100%[===================>] 400.64K  --.-KB/s    in 0.03s
#
# 2019-09-03 20:09:25 (12.8 MB/s) - ‘files.zip.3’ saved [410260/410260]
#
# Archive:  files.zip
#   inflating: md_result.png
#   inflating: __MACOSX/._md_result.png
#   inflating: tests/q01.py
#   inflating: tests/q05.py
#   inflating: tests/q04.py
#  extracting: tests/__init__.py
#   inflating: tests/qname.py
#   inflating: tests/q03.py
#   inflating: tests/q02.py
#   inflating: hm01.ok
#   inflating: notsaved.png
#   inflating: __MACOSX/._notsaved.png
#   inflating: Demographic_Statistics_By_Zip_Code.parq

# %%
from client.api.notebook import Notebook
ok = Notebook('lab01.ok')
_ = ok.auth(inline=True)

# %%
#Question 1
x=150
y=13*x
z=y/x**2
z
# Out:
# 0.08666666666666667

# %%
_ = ok.grade('q01')
# Out:
#
#
#         <p>All tests passed!</p>

# %%
#question 2
import math

# %%
m = math
m
# Out:
# <module 'math' (built-in)>

# %%
m=math.factorial(15)
m
# Out:
# 1307674368000

# %%
#Enter your updated markdown here Must match exactly
markdown="""
# Header
For the above header, make it an h1 tag using markdown. 

##### Sub-Header
For the above sub-header, make it an h5 tag using markdown. 

**Bold**

*Italics*

![](https://tw.rpi.edu//images/rpi-logo-red.jpg)  
Embed the above image.
"""

# %%
import hashlib 
result = hashlib.md5(markdown.encode()).hexdigest()
_ = ok.grade('q03')
# Out:
#
#
#         <p>All tests passed!</p>

# %%
#Run this cell to see if you passed the test.  If it fails, you probably didn't run the above required code. 
_ = ok.grade('q02')
# Out:
#
#
#         <p>All tests passed!</p>

# %%
pip install git+https://github.com/dask/fastparquet
# Out:
# Collecting git+https://github.com/dask/fastparquet
#   Cloning https://github.com/dask/fastparquet to /tmp/pip-req-build-680peo49
#   Running command git clone -q https://github.com/dask/fastparquet /tmp/pip-req-build-680peo49
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.6/dist-packages (from fastparquet==0.3.2) (0.24.2)
# Requirement already satisfied: numba>=0.28 in /usr/local/lib/python3.6/dist-packages (from fastparquet==0.3.2) (0.40.1)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from fastparquet==0.3.2) (1.16.4)
# Collecting thrift>=0.11.0 (from fastparquet==0.3.2)
#   Downloading https://files.pythonhosted.org/packages/c6/b4/510617906f8e0c5660e7d96fbc5585113f83ad547a3989b80297ac72a74c/thrift-0.11.0.tar.gz (52kB)
#      |████████████████████████████████| 61kB 4.1MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fastparquet==0.3.2) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->fastparquet==0.3.2) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->fastparquet==0.3.2) (2018.9)
# Requirement already satisfied: llvmlite>=0.25.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.28->fastparquet==0.3.2) (0.29.0)
# Building wheels for collected packages: fastparquet, thrift
#   Building wheel for fastparquet (setup.py) ... done
#   Created wheel for fastparquet: filename=fastparquet-0.3.2-cp36-cp36m-linux_x86_64.whl size=7126066 sha256=0c858a7a229929fb988fe10507b56b2a80aeff4714953f31c6ae1f136b986dba
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a2hb3si9/wheels/3c/f1/f2/fc6e12243fa9b94e6da52d2c0bb1d0cedf0cbb3a2da790fa88
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.11.0-cp36-cp36m-linux_x86_64.whl size=326448 sha256=afe1aed070f4953e32b6d07a20500795978925fbdba99c52495c7b7a2cedbf56
#   Stored in directory: /root/.cache/pip/wheels/be/36/81/0f93ba89a1cb7887c91937948519840a72c0ffdd57cac0ae8f
# Successfully built fastparquet thrift
# Installing collected packages: thrift, fastparquet
# Successfully installed fastparquet-0.3.2 thrift-0.11.0

# %%
#Question 4
# !wget https://github.com/rpi-techfundamentals/hm-01-starter/raw/master/Demographic_Statistics_By_Zip_Code.parq
# Out:
# --2019-09-03 20:10:10--  https://github.com/rpi-techfundamentals/hm-01-starter/raw/master/Demographic_Statistics_By_Zip_Code.parq
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rpi-techfundamentals/hm-01-starter/master/Demographic_Statistics_By_Zip_Code.parq [following]
# --2019-09-03 20:10:10--  https://raw.githubusercontent.com/rpi-techfundamentals/hm-01-starter/master/Demographic_Statistics_By_Zip_Code.parq
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 103532 (101K) [application/octet-stream]
# Saving to: ‘Demographic_Statistics_By_Zip_Code.parq.1’
#
# Demographic_Statist 100%[===================>] 101.11K  --.-KB/s    in 0.02s
#
# 2019-09-03 20:10:10 (4.63 MB/s) - ‘Demographic_Statistics_By_Zip_Code.parq.1’ saved [103532/103532]

# %%
#Run this to try to load the name.parq. It won't work unless you downloaded the file and installed the package. 
from fastparquet import ParquetFile  #This imports the package. 
pf = ParquetFile('Demographic_Statistics_By_Zip_Code.parq')
dfparq = pf.to_pandas()   #This changes the Parquet File object to a pandas dataframe. We will learn more about that later. 
dfparq  #Just listing the value prints it out.
# Out:
#      JURISDICTION NAME  ...  PERCENT PUBLIC ASSISTANCE TOTAL
# 0                10001  ...                              100
# 1                10002  ...                              100
# 2                10003  ...                              100
# 3                10004  ...                                0
# 4                10005  ...                              100
# 5                10006  ...                              100
# 6                10007  ...                              100
# 7                10009  ...                              100
# 8                10010  ...                                0
# 9                10011  ...                              100
# 10               10012  ...                                0
# 11               10013  ...                              100
# 12               10014  ...                                0
# 13               10016  ...                              100
# 14               10017  ...                                0
# 15               10018  ...                              100
# 16               10019  ...                                0
# 17               10020  ...                                0
# 18               10021  ...                                0
# 19               10022  ...                              100
# 20               10023  ...                              100
# 21               10024  ...                              100
# 22               10025  ...                              100
# 23               10026  ...                                0
# 24               10027  ...                              100
# 25               10028  ...                                0
# 26               10029  ...                              100
# 27               10030  ...                                0
# 28               10031  ...                                0
# 29               10032  ...                              100
# ..                 ...  ...                              ...
# 206              11731  ...                                0
# 207              11798  ...                              100
# 208              11968  ...                                0
# 209              12423  ...                              100
# 210              12428  ...                              100
# 211              12435  ...                              100
# 212              12458  ...                                0
# 213              12466  ...                              100
# 214              12473  ...                                0
# 215              12528  ...                              100
# 216              12701  ...                              100
# 217              12733  ...                              100
# 218              12734  ...                              100
# 219              12737  ...                              100
# 220              12750  ...                              100
# 221              12751  ...                              100
# 222              12754  ...                              100
# 223              12758  ...                              100
# 224              12759  ...                              100
# 225              12763  ...                              100
# 226              12764  ...                              100
# 227              12768  ...                              100
# 228              12779  ...                              100
# 229              12783  ...                              100
# 230              12786  ...                              100
# 231              12788  ...                              100
# 232              12789  ...                              100
# 233              13731  ...                              100
# 234              16091  ...                                0
# 235              20459  ...                                0
#
# [236 rows x 46 columns]

# %%
#Run this cell to see if you passed the test.  
_ = ok.grade('q04')
# Out:
#
#
#         <p>All tests passed!</p>

# %%
#Question 5

# !wget -O Demographic_Statistics_By_Zip_Code.csv https://data.cityofnewyork.us/api/views/kku6-nxdu/rows.csv?accessType=DOWNLOAD
# Out:
# --2019-09-03 20:10:21--  https://data.cityofnewyork.us/api/views/kku6-nxdu/rows.csv?accessType=DOWNLOAD
# Resolving data.cityofnewyork.us (data.cityofnewyork.us)... 52.206.140.199, 52.206.140.205, 52.206.68.26
# Connecting to data.cityofnewyork.us (data.cityofnewyork.us)|52.206.140.199|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘Demographic_Statistics_By_Zip_Code.csv’
#
# Demographic_Statist     [ <=>                ]  26.71K  --.-KB/s    in 0s
#
# 2019-09-03 20:10:22 (252 MB/s) - ‘Demographic_Statistics_By_Zip_Code.csv’ saved [27350]

# %%
# This will load the local name.csv file into a Pandas dataframe.  We will work with these a lot in the future.
import pandas as pd # This line imports the pandas package. 
dfcsv = pd.read_csv('Demographic_Statistics_By_Zip_Code.csv') 
dfcsv
# Out:
#      JURISDICTION NAME  ...  PERCENT PUBLIC ASSISTANCE TOTAL
# 0                10001  ...                              100
# 1                10002  ...                              100
# 2                10003  ...                              100
# 3                10004  ...                                0
# 4                10005  ...                              100
# 5                10006  ...                              100
# 6                10007  ...                              100
# 7                10009  ...                              100
# 8                10010  ...                                0
# 9                10011  ...                              100
# 10               10012  ...                                0
# 11               10013  ...                              100
# 12               10014  ...                                0
# 13               10016  ...                              100
# 14               10017  ...                                0
# 15               10018  ...                              100
# 16               10019  ...                                0
# 17               10020  ...                                0
# 18               10021  ...                                0
# 19               10022  ...                              100
# 20               10023  ...                              100
# 21               10024  ...                              100
# 22               10025  ...                              100
# 23               10026  ...                                0
# 24               10027  ...                              100
# 25               10028  ...                                0
# 26               10029  ...                              100
# 27               10030  ...                                0
# 28               10031  ...                                0
# 29               10032  ...                              100
# ..                 ...  ...                              ...
# 206              11731  ...                                0
# 207              11798  ...                              100
# 208              11968  ...                                0
# 209              12423  ...                              100
# 210              12428  ...                              100
# 211              12435  ...                              100
# 212              12458  ...                                0
# 213              12466  ...                              100
# 214              12473  ...                                0
# 215              12528  ...                              100
# 216              12701  ...                              100
# 217              12733  ...                              100
# 218              12734  ...                              100
# 219              12737  ...                              100
# 220              12750  ...                              100
# 221              12751  ...                              100
# 222              12754  ...                              100
# 223              12758  ...                              100
# 224              12759  ...                              100
# 225              12763  ...                              100
# 226              12764  ...                              100
# 227              12768  ...                              100
# 228              12779  ...                              100
# 229              12783  ...                              100
# 230              12786  ...                              100
# 231              12788  ...                              100
# 232              12789  ...                              100
# 233              13731  ...                              100
# 234              16091  ...                                0
# 235              20459  ...                                0
#
# [236 rows x 46 columns]

# %%
#Run this cell to see if you passed the test.  
_ = ok.grade('q05')
# Out:
#
#
#         <p>All tests passed!</p>

# %%
# summarize 3 reasons why Git and Github are important tools for data scientists.
man1= "A platform increase work efficiencies by helping data scientists collaborate on prjects even though they are in different area "
man2="the Git and Gitup is version control system make data scientists work on prjects in a distributed way which mean everyone can change and share codes with each other"
man3="The Git and Gitup are great platform which can help data scientists organize their works and integrate with other popular editors"

# %%
course="mgmt6560"   #course number
section="01"          #section 
first_name="Tong"   #For example, "jason"
last_name="Chen"    #For example, "kuruzovich"
student_id="661984914"       #for example "kuruzj"
student_email="chent17@rpi.edu"    #for example "kuruzj@rpi.edu"
collaborators = "just myself"  #You can speak with others regarding the assignment, but all typed work must be your own.

# %%
_ = ok.grade('qname')
# Out:
#
#
#         <p>All tests passed!</p>

# %%
#Please run this at end to show that all tests were passed. 
import os
_ = [ok.grade(q[:-3]) for q in os.listdir("tests") if q.startswith('q')]
# Out:
#
#
#         <p>All tests passed!</p>
#
#
#         <p>All tests passed!</p>
#
#
#         <p>All tests passed!</p>
#
#
#         <p>All tests passed!</p>
#
#
#         <p>All tests passed!</p>
#
#
#         <p>All tests passed!</p>
